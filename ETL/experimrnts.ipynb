# %%
import pandas as pd
from pathlib import Path
import logging as log





DATA = Path.cwd().parent.parent  /"DATASET"/"water_potability.csv"



print(DATA)
# Out:
# c:\Users\IGO\OneDrive\Bureau\WATER\DATASET\water_potability.csv

# %%
class Extraction:
    def __init__(self, source_path):
        self.source_path = source_path

    def extract_data(self) -> pd.DataFrame:
        
        try:
            # Check if the source path exists
            if not Path(self.source_path).exists():
                
                raise FileNotFoundError(f"Source path {self.source_path} does not exist.")

            # Read the data into a DataFrame
            data = pd.read_csv(self.source_path)
            
            return data

        except Exception as e:
            
            raise

# %%
# file checking


def file_cheking(path):


    






    return

# %%
f=Extraction(DATA).extract_data()
f.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
class Dataloader:
    def __init__(self,data_path:str):
        self.data_path = data_path


    def loading(self):


        DATA = Path.cwd().parent.parent  /"DATASET"/"water_potability.csv"
        return pd.read_csv(DATA)

# %%
kika = Dataloader(DATA).loading()
kika.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
if not DATA.is_file():
    raise FileNotFoundError(f"File not found: {DATA}")

df = pd.read_csv(DATA)

print(df.head())
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
def inspect_data(self):

        data = Extraction(self.path).extract_data()

        print("Data Inspection: start" ,data.head())

# %%
print("=" * 70)
print("                    DATASET INSPECTION REPORT")
print("=" * 70)
# Out:
# ...
#                     DATASET INSPECTION REPORT
# ...

# %%
duplicate_rows = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")


duplicate_percentage = (
    df.apply(lambda col: col.duplicated().mean() * 100)
      .round(2)
      .sort_values(ascending=False)
)

print(duplicate_percentage)
# Out:
# Number of duplicate rows: 0
# Potability         99.94
# Sulfate            23.81
# ph                 14.96
# Trihalomethanes     4.91
# Hardness            0.00
# Solids              0.00
# Conductivity        0.00
# Chloramines         0.00
# Organic_carbon      0.00
# Turbidity           0.00
# dtype: float64

# %%
sum = df.duplicated().sum()
mean =  df.duplicated().mean() 

print(f"Total duplicate rows: {sum}")
print(f"Percentage of duplicate rows: {mean }%")
# Out:
# Total duplicate rows: 0
# Percentage of duplicate rows: 0.0%

# %%
print("\n GENERAL INFORMATION")
print("-" * 70)

dimentions = df.shape
rows, columns = df.shape
duplicate_rows = df.duplicated().sum()
duplicate_percentage = duplicate_rows / len(df) * 100

print(f"Dimensions            : {dimentions}")
print(f"Rows                  : {rows:,}")
print(f"Columns               : {columns:,}")
print(f"Duplicate Rows        : {duplicate_rows:,}")
print(f"Duplicate Rows (%)    : {duplicate_percentage:.2f}%")
# Out:
#  GENERAL INFORMATION
# ----------------------------------------------------------------------
# Dimensions            : (3276, 10)
# Rows                  : 3,276
# Columns               : 10
# Duplicate Rows        : 0
# Duplicate Rows (%)    : 0.00%

# %%
#head of the dataset
#print(f"head of the dataset: {df.head().to_string()}")


#tail of the dataset
#print(f"tail of the dataset: {df.tail().to_string()}")

# %%
missing = (
    df.isnull()
      .mean()
      .mul(100)
      .round(2)
      .sort_values(ascending=False) 
)
print(missing.to_string())
# Out:
# Sulfate            23.84
# ph                 14.99
# Trihalomethanes     4.95
# Hardness            0.00
# Chloramines         0.00
# Solids              0.00
# Conductivity        0.00
# Organic_carbon      0.00
# Turbidity           0.00
# Potability          0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
from kika import zInspection

inspection = zInspection(df)

inspection.inspect_data()
# Out:
# ...
#                  DATASET INSPECTION REPORT
# ...
#
# GENERAL INFORMATION
# ----------------------------------------------------------------------
# Dimensions             : (3276, 10)
# Rows                   : 3,276
# Columns                : 10
# Duplicate Rows         : 0
# Duplicate Rows (%)     : 0.00%
#
# COLUMN INFORMATION
# ----------------------------------------------------------------------
#                 Data Type  Non-Missing  Missing  Missing %  Duplicate Values %  Duplicated Column
# Chloramines       float64         3276        0       0.00                0.00              False
# Conductivity      float64         3276        0       0.00                0.00              False
# Hardness          float64         3276        0       0.00                0.00              False
# Organic_carbon    float64         3276        0       0.00                0.00              False
# ...

# %%
# cheking for file existance




if not DATA.exists():
    print("Path does not exist")


if not DATA.is_file():
    print("The path does not point to a file")


if DATA.suffix.lower() != ".csv":
    print("File is not a CSV")


if DATA.stat().st_size == 0:
    print("File is empty")



if df.empty:
    print("Dataset is empty")
else:
    print("Dataset contains data")
# Out:
# Dataset contains data

# %%
print(DATA.stat().st_size)
# Out:
# 525187

# %%
try:
    df = pd.read_csv(DATA)
    print("CSV loaded successfully")
    df.head()

except Exception as e:
    print(f"Failed to read CSV: {e}")
# Out:
# CSV loaded successfully

# %%
expected_columns = {
    "ph",
    "Hardness",
    "Solids",
    "Chloramines",
    "Sulfate",
    "Conductivity",
    "Organic_carbon",
    "Trihalomethanes",
    "Turbidity",
    "Potability"
}



actual_columns = set(df.columns)

missing_columns = expected_columns - actual_columns
unexpected_columns = actual_columns - expected_columns

print("Missing:", missing_columns)
print("Unexpected:", unexpected_columns)
# Out:
# Missing: set()
# Unexpected: set()
